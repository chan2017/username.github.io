# %% [markdown]
# <h1>THE PRICE OF GAS INFLUENCES THE AUTO MARKET</h1>

# %% [markdown]
# <img src =https://n6-img-fp.akamaized.net/free-vector/petrol-station-design_1454-41.jpg?size=338&ext=jpg>

# %% [markdown]
# <h3>MOTIVATION</h3>

# %% [markdown]
# <p>
# When thinking about what type of final project we wanted to do, we wanted a topic that we can extract years of data from as well as be a topic that applies to current times. What we have selected was the Fuel economy data that contained fuel economy data from as far as 1978 but for this project we'll be focusing on years 2001 - 2017. The reason we used this time range is due to only wanting to use data within the 2000s while having enough data for formulate more accurate findings. With this data, we also wanted to have a correlations with the price of gas and the types of cars that people bought that year. By the end of this tutorial, you'll find out whether gas prices influence the purchase of cars for the current year.
# </p>

# %%
#DEPRSSION DIDN'T WIN THIS TIME AHAHAHAHAHAHAHAH
# %matplotlib inline
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import sklearn
from statsmodels.formula.api import ols
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
data_2001 = pd.read_csv("2001.csv")
data_2001['year'] = 2001

data_2002 = pd.read_csv("2002.csv")
data_2002['year'] = 2002

data_2005 = pd.read_csv("2005.csv")
data_2005['year'] = 2005

data_2006 = pd.read_csv("2006.csv")
data_2006['year'] = 2006

data_2007 = pd.read_csv("2007.csv")
data_2007['year'] = 2007

data_2008 = pd.read_csv("2008.csv")
data_2008['year'] = 2008

data_2003 = pd.read_csv("2003.csv")
data_2003['year'] = 2003

data_2004 = pd.read_csv("2004.csv")
data_2004['year'] = 2004

data_2009 = pd.read_csv("2009.csv")
data_2009['year'] = 2009

data_2010 = pd.read_csv("2010.csv")
data_2010['year'] = 2010

data_2011 = pd.read_csv("2011.csv")
data_2011['year'] = 2011

data_2012 = pd.read_csv("2012.csv")
data_2012['year'] = 2012

data_2013 = pd.read_csv("2013.csv")
data_2013['year'] = 2013

data_2014 = pd.read_csv("2014.csv")
data_2014['year'] = 2014

data_2015 = pd.read_csv("2015.csv")
data_2015['year'] = 2015

data_2016 = pd.read_csv("2016.csv")
data_2016['year'] = 2016

data_2017 = pd.read_csv("2017.csv")
data_2017['year'] = 2017

fig = plt.figure()
plt.xlabel('Annual Fuel Cost')
plt.ylabel('CITY (MPG)')

cur = data_2001
i = cur['fcost']
j = cur['cty']
plt.scatter(i,j, color = 'red',label = '2001')

cur = data_2002
i = cur['fcost']
j = cur['cty']
plt.scatter(i,j, color = 'green',label = '2002')

cur = data_2003
i = cur['fcost']
j = cur['cty']
plt.scatter(i,j, color = 'yellow',label = '2003')

cur = data_2004
i = cur['fcost']
j = cur['cty']
plt.scatter(i,j, color = 'blue',label = '2004')

cur = data_2005
i = cur['fcost']
j = cur['cty']
plt.scatter(i,j, color = 'black',label = '2005')
plt.legend()
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (12,13,14,18,19,23,31,55,56,57,58,59,62,67,74,75,78,80,84,85,88,93,96,98,99,100,103,105,106,107,109) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (12,13,14,18,19,23,31,55,56,57,58,59,62,67,74,75,78,80,84,85,88,93,96,97,98,99,100,103,105,106,107,109,113,114,115,118,121,122,125,129,183) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
fig = plt.figure()
plt.xlabel('Annual Fuel Cost')
plt.ylabel('HIGHWAY (MPG)')

cur = data_2001
i = cur['fcost']
j = cur['hwy']
plt.scatter(i,j, color = 'red',label = '2001')

cur = data_2002
i = cur['fcost']
j = cur['hwy']
plt.scatter(i,j, color = 'green',label = '2002')

cur = data_2003
i = cur['fcost']
j = cur['hwy']
plt.scatter(i,j, color = 'yellow',label = '2003')

cur = data_2004
i = cur['fcost']
j = cur['hwy']
plt.scatter(i,j, color = 'blue',label = '2004')

cur = data_2005
i = cur['fcost']
j = cur['hwy']
plt.scatter(i,j, color = 'black',label = '2005')
plt.legend()

# %%
fig = plt.figure()
plt.xlabel('Annual Fuel Cost')
plt.ylabel('CITY (MPG)')

cur = data_2006
i = cur['ANL FL CST']
j = cur['CITY MPG (GUIDE)']
plt.scatter(i,j, color = 'red',label = '2006')

cur = data_2007
i = cur['ANL FL CST']
j = cur['CITY MPG (GUIDE)']
plt.scatter(i,j, color = 'green',label = '2007')

cur = data_2008
i = cur['ANL FL CST']
j = cur['CITY MPG (GUIDE)']
plt.scatter(i,j, color = 'yellow',label = '2008')

cur = data_2009
i = cur['ANL FL CST']
j = cur['CITY MPG (GUIDE)']
plt.scatter(i,j, color = 'blue',label = '2009')

plt.legend()

# %%
fig = plt.figure()
plt.xlabel('Annual Fuel Cost')
plt.ylabel('HIGHWAY (MPG)')

cur = data_2006
i = cur['ANL FL CST']
j = cur['HWY MPG (GUIDE)']
plt.scatter(i,j, color = 'red',label = '2006')

cur = data_2007
i = cur['ANL FL CST']
j = cur['HWY MPG (GUIDE)']
plt.scatter(i,j, color = 'green',label = '2007')

cur = data_2008
i = cur['ANL FL CST']
j = cur['HWY MPG (GUIDE)']
plt.scatter(i,j, color = 'yellow',label = '2008')

cur = data_2009
i = cur['ANL FL CST']
j = cur['HWY MPG (GUIDE)']
plt.scatter(i,j, color = 'blue',label = '2009')

plt.legend()

# %%
fig = plt.figure()
plt.xlabel('Annual Fuel Cost')
plt.ylabel('CITY (MPG)')

cur = data_2010
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['City FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'red',label = '2010')

cur = data_2011
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['City FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'green',label = '2011')

cur = data_2012
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['City FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'yellow',label = '2012')

cur = data_2013
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['City FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'blue',label = '2013')

cur = data_2014
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['City FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'orange',label = '2014')

cur = data_2015
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['City FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'cyan',label = '2015')

cur = data_2016
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['City FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'brown',label = '2016')

# cur = data_2017
# i = cur['Annual Fuel1 Cost - Conventional Fuel']
# j = cur['City FE (Guide) - Conventional Fuel']
# plt.scatter(i,j, color = 'pink',label = '2017')

plt.legend()

# %%
fig = plt.figure()
plt.xlabel('Annual Fuel Cost')
plt.ylabel('HIGHWAY (MPG)')

cur = data_2010
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['Hwy FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'red',label = '2010')

cur = data_2011
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['Hwy FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'green',label = '2011')

cur = data_2012
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['Hwy FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'yellow',label = '2012')

cur = data_2013
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['Hwy FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'blue',label = '2013')

cur = data_2014
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['Hwy FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'orange',label = '2014')

cur = data_2015
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['Hwy FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'cyan',label = '2015')

cur = data_2016
i = cur['Annual Fuel1 Cost - Conventional Fuel']
j = cur['Hwy FE (Guide) - Conventional Fuel']
plt.scatter(i,j, color = 'brown',label = '2016')

# cur = data_2017
# i = cur['Annual Fuel1 Cost - Conventional Fuel']
# j = cur['City FE (Guide) - Conventional Fuel']
# plt.scatter(i,j, color = 'pink',label = '2017')

plt.legend()

# %%
fig = plt.figure()
plt.xlabel('YEAR')
plt.ylabel('CITY (MPG)')

data_arr_2001_2005 = [data_2001, data_2002, data_2003, data_2004, data_2005] 
data_arr_2006_2009 = [data_2006, data_2007, data_2008, data_2009] 
data_arr_2010_2013 = [data_2010, data_2011,data_2012, data_2013] 
data_arr_2014_2017 = [data_2014, data_2015, data_2016, data_2017]

for idx in data_arr_2001_2005:
    i = idx['year']
    j = idx['cty']
    plt.scatter(i,j, color = 'red')

for idx in data_arr_2006_2009:
        i = idx['year']
        j = idx['CITY MPG (GUIDE)']
        plt.scatter(i,j, color = 'blue')
            
for idx in data_arr_2010_2013:
    i = idx['year']
    j = idx['City FE (Guide) - Conventional Fuel']
    plt.scatter(i,j, color = 'orange')    

for idx in data_arr_2014_2017:
    i = idx['year']
    j = idx['City FE (Guide) - Conventional Fuel']
    plt.scatter(i,j, color = 'brown')

plt.legend()

# %%
fig = plt.figure()
plt.xlabel('YEAR')
plt.ylabel('CITY (MPG)')

data_arr_2001_2005 = [data_2001, data_2002, data_2003, data_2004, data_2005] 
data_arr_2006_2009 = [data_2006, data_2007, data_2008, data_2009] 
data_arr_2010_2013 = [data_2010, data_2011,data_2012, data_2013] 
data_arr_2014_2017 = [data_2014, data_2015, data_2016, data_2017]

for idx in data_arr_2001_2005:
    i = idx['year']
    j = idx['hwy']
    plt.scatter(i,j)

for idx in data_arr_2006_2009:
        i = idx['year']
        j = idx['HWY MPG (GUIDE)']
        plt.scatter(i,j)
            
for idx in data_arr_2010_2013:
    i = idx['year']
    j = idx['Hwy FE (Guide) - Conventional Fuel']
    plt.scatter(i,j)    

for idx in data_arr_2014_2017:
    i = idx['year']
    j = idx['Hwy FE (Guide) - Conventional Fuel']
    plt.scatter(i,j)

plt.legend()

# %%
fig = plt.figure()
plt.xlabel('YEAR')
plt.ylabel('HWY (MPG)')

data_arr_2001_2005 = [data_2001, data_2002, data_2003, data_2004, data_2005] 
data_arr_2006_2009 = [data_2006, data_2007, data_2008, data_2009] 
data_arr_2010_2013 = [data_2010, data_2011,data_2012, data_2013] 
data_arr_2014_2017 = [data_2014, data_2015, data_2016, data_2017]

for idx in data_arr_2001_2005:
    i = idx['fl']
    j = idx['hwy']
    plt.scatter(i,j, color = 'red')

for idx in data_arr_2006_2009:
        i = idx['year']
        j = idx['HWY MPG (GUIDE)']
        plt.scatter(i,j, color = 'blue')
            
for idx in data_arr_2010_2013:
    i = idx['year']
    j = idx['Hwy FE (Guide) - Conventional Fuel']
    plt.scatter(i,j, color = 'orange')    

for idx in data_arr_2014_2017:
    i = idx['year']
    j = idx['Hwy FE (Guide) - Conventional Fuel']
    plt.scatter(i,j, color = 'brown')

plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-da3644aa7b1e> in <module>()
#      11     i = idx['fl']
#      12     j = idx['hwy']
# ---> 13     plt.scatter(i,j, color = 'red')
#      14
#      15 for idx in data_arr_2006_2009:
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3432                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3433                          linewidths=linewidths, verts=verts,
# -> 3434                          edgecolors=edgecolors, data=data, **kwargs)
#    3435     finally:
#    3436         ax._hold = washold
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
# ...
